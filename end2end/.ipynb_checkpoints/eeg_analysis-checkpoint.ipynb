# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.contrib import rnn
from sklearn.utils import shuffle
import os
import shutil
from scipy.io import loadmat
import scipy as sp
from load_foot import Load_data
from scipy import signal
# %matplotlib inline

# %%
data = Load_data()
train, tr_label, test, te_label = data.split()

# %%
W = np.array([1,-0.25,-0.25,-0.25,-0.25])
X = np.dot(train, W)
t = np.arange(0,len(X)) / 128

# %%
widths = np.arange(1, 28)
cwtmatr = signal.cwt(X, signal.ricker, widths)
plt.imshow(cwtmatr[:,2049:4100], extent=[-1, 1, 1, 31], cmap='PRGn', aspect='auto',
           vmax=abs(cwtmatr).max(), vmin=-abs(cwtmatr).max())

# %%
data2 = Load_data()
data2.ica()
X2,_,_,_ = data2.split()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-4ff0f1a41a23> in <module>()
#       1 data2 = Load_data()
# ----> 2 data2.ica()
#       3 X2,_,_,_ = data2.split()
#
# AttributeError: 'Load_data' object has no attribute 'ica'

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-25b7bc09bf5e> in <module>()
#       1 widths = np.arange(1, 28)
# ----> 2 cwtmatr = signal.cwt(X2, signal.ricker, widths)
#       3 plt.imshow(cwtmatr[:,2049:4100], extent=[-1, 1, 1, 31], cmap='PRGn', aspect='auto',
#       4            vmax=abs(cwtmatr).max(), vmin=-abs(cwtmatr).max())
#
# /home/hs/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/scipy/signal/wavelets.py in cwt(data, wavelet, widths)
#     362         wavelet_data = wavelet(min(10 * width, len(data)), width)
#     363         output[ind, :] = convolve(data, wavelet_data,
# --> 364                                   mode='same')
#     365     return output
#
# /home/hs/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/scipy/signal/signaltools.py in convolve(in1, in2, mode)
#     462
# ...
